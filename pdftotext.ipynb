# %%
from PIL import Image
import pytesseract
from utils import *

# %%
doc_path = "./document/sample.pdf"
images_list = pdf2image(doc_path)
# Out:
# [INFO] NUMNER OF PAGE : 2

# %% [markdown]
# ## **Page1 From Sample.pdf**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))
plt.imshow(images_list[0], cmap="gray")

# %%
## for page1 
text = pytesseract.image_to_string(images_list[0])
print(text)
# Out:
# A Simple PDF File
#
# This is a small demonstration .pdf file -
#
# just for use in the Virtual Mechanics tutorials. More text. And more
# text. And more text. And more text. And more text.
#
# And more text. And more text. And more text. And more text. And more
# text. And more text. Boring, zzzzz. And more text. And more text. And
# more text. And more text. And more text. And more text. And more text.
# And more text. And more text.
#
# And more text. And more text. And more text. And more text. And more
# text. And more text. And more text. Even more. Continued on page 2 ...

# %% [markdown]
# ## **Page2 From Sample.pdf**

# %%
plt.figure(figsize=(12, 12))
plt.imshow(images_list[1], cmap="gray")

# %%
## for page1 
text = pytesseract.image_to_string(images_list[1])
print(text)
# Out:
# Simple PDF File 2
#
# ...continued from page 1. Yet more text. And more text. And more text.
# And more text. And more text. And more text. And more text. And more
# text. Oh, how boring typing this stuff. But not as boring as watching
# paint dry. And more text. And more text. And more text. And more text.
# Boring. More, a little more text. The end, and just as well.
